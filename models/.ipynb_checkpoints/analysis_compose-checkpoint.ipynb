# %% [markdown]
# # Analysis of traffic light + vehicle
# Nok Wongpiromsarn, 3 March 2020
#
# ## Problem description
# This example illustrates the use of TuLiP interface to stormpy to analyze a probabilistic model obtained from the composition of 2 Markov chains.
#
# ![Screenshot%20from%202020-03-03%2013-14-16.png](attachment:Screenshot%20from%202020-03-03%2013-14-16.png)
#
# We begin by importing the packages and modules that we will need.

# %%
import os
from tulip.interfaces import stormpy as stormpy_int
from tulip.transys.compositions import synchronous_parallel
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`
# `omega.symbolic.symbolic` failed to import `dd.cudd`.
# Will use `dd.autoref`.
# `tulip` failed to import `cvxopt`.
# No quadratic cost for controller computation.

# %% [markdown]
# Set up paths to all the models

# %%
model_path = os.path.join("/home/rayhanul/Documents/GitHub/Autonomous_system", "models")
ma_path = os.path.join(model_path, "ma.nm")
mh_path = os.path.join(model_path, "mh.pm")
light_path = os.path.join(model_path, "light.pm")

# %% [markdown]
# Build models from prism files

# %%
ma = stormpy_int.to_tulip_transys(ma_path)
mh = stormpy_int.to_tulip_transys(mh_path)
light = stormpy_int.to_tulip_transys(light_path)

# %% [markdown]
# Compose models

# %%
composed = synchronous_parallel([mh, light, ma])
print(composed)
# Out:
# Kripke Structure:
# ----------------------------------------
# Atomic Propositions (APs):
# 	MathSet(['a9', 'h3', 'red', 'h4', 'h6', 'a4', 'green', 'a8', 'h0', 'h2', 'h5', 'h1'])
#
# States labeled with sets of APs:
# 	 State: ('s2', 's1', 's2'), AP: {'h2', 'a9', 'red'}
# 	 State: ('s2', 's1', 's1'), AP: {'a4', 'h2', 'red'}
# 	 State: ('s2', 's1', 's0'), AP: {'a8', 'h2', 'red'}
# 	 State: ('s2', 's0', 's2'), AP: {'green', 'h2', 'a9'}
# 	 State: ('s2', 's0', 's1'), AP: {'a4', 'green', 'h2'}
# 	 State: ('s2', 's0', 's0'), AP: {'green', 'h2', 'a8'}
# 	 State: ('s3', 's1', 's2'), AP: {'h3', 'red', 'a9'}
# 	 State: ('s3', 's1', 's1'), AP: {'h3', 'a4', 'red'}
# 	 State: ('s3', 's1', 's0'), AP: {'h3', 'a8', 'red'}
# 	 State: ('s3', 's0', 's2'), AP: {'h3', 'green', 'a9'}
# 	 State: ('s3', 's0', 's1'), AP: {'h3', 'green', 'a4'}
# 	 State: ('s3', 's0', 's0'), AP: {'h3', 'green', 'a8'}
# 	 State: ('s1', 's1', 's2'), AP: {'red', 'a9', 'h1'}
# 	 State: ('s1', 's1', 's1'), AP: {'a4', 'red', 'h1'}
# 	 State: ('s1', 's1', 's0'), AP: {'a8', 'red', 'h1'}
# 	 State: ('s1', 's0', 's2'), AP: {'green', 'a9', 'h1'}
# 	 State: ('s1', 's0', 's1'), AP: {'a4', 'green', 'h1'}
# 	 State: ('s1', 's0', 's0'), AP: {'green', 'a8', 'h1'}
# 	 State: ('s0', 's1', 's2'), AP: {'h0', 'red', 'a9'}
# 	 State: ('s0', 's1', 's1'), AP: {'h0', 'a4', 'red'}
# 	 State: ('s0', 's1', 's0'), AP: {'h0', 'a8', 'red'}
# 	 State: ('s0', 's0', 's2'), AP: {'h0', 'green', 'a9'}
# 	 State: ('s0', 's0', 's1'), AP: {'h0', 'green', 'a4'}
# 	 State: ('s0', 's0', 's0'), AP: {'h0', 'green', 'a8'}
# 	 State: ('s5', 's1', 's2'), AP: {'h5', 'red', 'a9'}
# 	 State: ('s5', 's1', 's1'), AP: {'h5', 'a4', 'red'}
# 	 State: ('s5', 's1', 's0'), AP: {'h5', 'a8', 'red'}
# 	 State: ('s5', 's0', 's2'), AP: {'h5', 'green', 'a9'}
# 	 State: ('s5', 's0', 's1'), AP: {'h5', 'green', 'a4'}
# 	 State: ('s5', 's0', 's0'), AP: {'h5', 'green', 'a8'}
# 	 State: ('s4', 's1', 's2'), AP: {'red', 'a9', 'h4'}
# 	 State: ('s4', 's1', 's1'), AP: {'a4', 'red', 'h4'}
# 	 State: ('s4', 's1', 's0'), AP: {'a8', 'red', 'h4'}
# 	 State: ('s4', 's0', 's2'), AP: {'green', 'a9', 'h4'}
# 	 State: ('s4', 's0', 's1'), AP: {'a4', 'green', 'h4'}
# 	 State: ('s4', 's0', 's0'), AP: {'green', 'a8', 'h4'}
# 	 State: ('s6', 's1', 's2'), AP: {'red', 'a9', 'h6'}
# 	 State: ('s6', 's1', 's1'), AP: {'a4', 'red', 'h6'}
# 	 State: ('s6', 's1', 's0'), AP: {'a8', 'red', 'h6'}
# 	 State: ('s6', 's0', 's2'), AP: {'green', 'a9', 'h6'}
# 	 State: ('s6', 's0', 's1'), AP: {'a4', 'green', 'h6'}
# 	 State: ('s6', 's0', 's0'), AP: {'green', 'a8', 'h6'}
#
#
# Initial States:
# SubSet([('s0', 's0', 's0')])
#
# Transitions:
# OutMultiEdgeDataView([(('s2', 's1', 's2'), ('s2', 's0', 's2')), (('s2', 's1', 's2'), ('s2', 's1', 's2')), (('s2', 's1', 's2'), ('s3', 's0', 's2')), (('s2', 's1', 's2'), ('s3', 's1', 's2')), (('s2', 's1', 's1'), ('s2', 's0', 's1')), (('s2', 's1', 's1'), ('s2', 's0', 's1')), (('s2', 's1', 's1'), ('s2', 's0', 's2')), (('s2', 's1', 's1'), ('s2', 's0', 's2')), (('s2', 's1', 's1'), ('s2', 's1', 's1')), (('s2', 's1', 's1'), ('s2', 's1', 's1')), (('s2', 's1', 's1'), ('s2', 's1', 's2')), (('s2', 's1', 's1'), ('s2', 's1', 's2')), (('s2', 's1', 's1'), ('s3', 's0', 's1')), (('s2', 's1', 's1'), ('s3', 's0', 's1')), (('s2', 's1', 's1'), ('s3', 's0', 's2')), (('s2', 's1', 's1'), ('s3', 's0', 's2')), (('s2', 's1', 's1'), ('s3', 's1', 's1')), (('s2', 's1', 's1'), ('s3', 's1', 's1')), (('s2', 's1', 's1'), ('s3', 's1', 's2')), (('s2', 's1', 's1'), ('s3', 's1', 's2')), (('s2', 's1', 's0'), ('s2', 's0', 's0')), (('s2', 's1', 's0'), ('s2', 's0', 's0')), (('s2', 's1', 's0'), ('s2', 's0', 's1')), (('s2', 's1', 's0'), ('s2', 's0', 's1')), (('s2', 's1', 's0'), ('s2', 's1', 's0')), (('s2', 's1', 's0'), ('s2', 's1', 's0')), (('s2', 's1', 's0'), ('s2', 's1', 's1')), (('s2', 's1', 's0'), ('s2', 's1', 's1')), (('s2', 's1', 's0'), ('s3', 's0', 's0')), (('s2', 's1', 's0'), ('s3', 's0', 's0')), (('s2', 's1', 's0'), ('s3', 's0', 's1')), (('s2', 's1', 's0'), ('s3', 's0', 's1')), (('s2', 's1', 's0'), ('s3', 's1', 's0')), (('s2', 's1', 's0'), ('s3', 's1', 's0')), (('s2', 's1', 's0'), ('s3', 's1', 's1')), (('s2', 's1', 's0'), ('s3', 's1', 's1')), (('s2', 's0', 's2'), ('s2', 's0', 's2')), (('s2', 's0', 's2'), ('s2', 's1', 's2')), (('s2', 's0', 's2'), ('s3', 's0', 's2')), (('s2', 's0', 's2'), ('s3', 's1', 's2')), (('s2', 's0', 's1'), ('s2', 's0', 's1')), (('s2', 's0', 's1'), ('s2', 's0', 's1')), (('s2', 's0', 's1'), ('s2', 's0', 's2')), (('s2', 's0', 's1'), ('s2', 's0', 's2')), (('s2', 's0', 's1'), ('s2', 's1', 's1')), (('s2', 's0', 's1'), ('s2', 's1', 's1')), (('s2', 's0', 's1'), ('s2', 's1', 's2')), (('s2', 's0', 's1'), ('s2', 's1', 's2')), (('s2', 's0', 's1'), ('s3', 's0', 's1')), (('s2', 's0', 's1'), ('s3', 's0', 's1')), (('s2', 's0', 's1'), ('s3', 's0', 's2')), (('s2', 's0', 's1'), ('s3', 's0', 's2')), (('s2', 's0', 's1'), ('s3', 's1', 's1')), (('s2', 's0', 's1'), ('s3', 's1', 's1')), (('s2', 's0', 's1'), ('s3', 's1', 's2')), (('s2', 's0', 's1'), ('s3', 's1', 's2')), (('s2', 's0', 's0'), ('s2', 's0', 's0')), (('s2', 's0', 's0'), ('s2', 's0', 's0')), (('s2', 's0', 's0'), ('s2', 's0', 's1')), (('s2', 's0', 's0'), ('s2', 's0', 's1')), (('s2', 's0', 's0'), ('s2', 's1', 's0')), (('s2', 's0', 's0'), ('s2', 's1', 's0')), (('s2', 's0', 's0'), ('s2', 's1', 's1')), (('s2', 's0', 's0'), ('s2', 's1', 's1')), (('s2', 's0', 's0'), ('s3', 's0', 's0')), (('s2', 's0', 's0'), ('s3', 's0', 's0')), (('s2', 's0', 's0'), ('s3', 's0', 's1')), (('s2', 's0', 's0'), ('s3', 's0', 's1')), (('s2', 's0', 's0'), ('s3', 's1', 's0')), (('s2', 's0', 's0'), ('s3', 's1', 's0')), (('s2', 's0', 's0'), ('s3', 's1', 's1')), (('s2', 's0', 's0'), ('s3', 's1', 's1')), (('s3', 's1', 's2'), ('s3', 's0', 's2')), (('s3', 's1', 's2'), ('s3', 's1', 's2')), (('s3', 's1', 's2'), ('s4', 's0', 's2')), (('s3', 's1', 's2'), ('s4', 's1', 's2')), (('s3', 's1', 's1'), ('s3', 's0', 's1')), (('s3', 's1', 's1'), ('s3', 's0', 's1')), (('s3', 's1', 's1'), ('s3', 's0', 's2')), (('s3', 's1', 's1'), ('s3', 's0', 's2')), (('s3', 's1', 's1'), ('s3', 's1', 's1')), (('s3', 's1', 's1'), ('s3', 's1', 's1')), (('s3', 's1', 's1'), ('s3', 's1', 's2')), (('s3', 's1', 's1'), ('s3', 's1', 's2')), (('s3', 's1', 's1'), ('s4', 's0', 's1')), (('s3', 's1', 's1'), ('s4', 's0', 's1')), (('s3', 's1', 's1'), ('s4', 's0', 's2')), (('s3', 's1', 's1'), ('s4', 's0', 's2')), (('s3', 's1', 's1'), ('s4', 's1', 's1')), (('s3', 's1', 's1'), ('s4', 's1', 's1')), (('s3', 's1', 's1'), ('s4', 's1', 's2')), (('s3', 's1', 's1'), ('s4', 's1', 's2')), (('s3', 's1', 's0'), ('s3', 's0', 's0')), (('s3', 's1', 's0'), ('s3', 's0', 's0')), (('s3', 's1', 's0'), ('s3', 's ...
# ----------------------------------------

# %% [markdown]
# Specify property: "The light is green until the vehicle reaches c6"
#
# ## Exercise: Change the formula such that it corresponds to "The vehicle is never at c4 or c5 when the light is red"

# %%
formula = 'P=? [ "green" U "h6" ]'

# %% [markdown]
# Run model checking

# %%
out_model_path = os.path.join(model_path, "out_composed_model.nm")
result = stormpy_int.model_checking(composed, formula, out_model_path)

# %% [markdown]
# Examine result

# %%
for state in composed.states:
    print("  State {}, with labels {}, Pr = {}".format(state, composed.states[state]["ap"], result[state]))
# Out:
#   State ('s0', 's0'), with labels {'green', 'h0'}, Pr = 0.2445198611698898
#   State ('s0', 's1'), with labels {'red', 'h0'}, Pr = 0.0
#   State ('s5', 's0'), with labels {'h5', 'green'}, Pr = 0.9523809523809521
#   State ('s5', 's1'), with labels {'h5', 'red'}, Pr = 0.0
#   State ('s6', 's0'), with labels {'h6', 'green'}, Pr = 1.0
#   State ('s6', 's1'), with labels {'h6', 'red'}, Pr = 1.0
#   State ('s4', 's0'), with labels {'green', 'h4'}, Pr = 0.7256235827664395
#   State ('s4', 's1'), with labels {'red', 'h4'}, Pr = 0.0
#   State ('s1', 's0'), with labels {'h1', 'green'}, Pr = 0.3209323177854804
#   State ('s1', 's1'), with labels {'h1', 'red'}, Pr = 0.0
#   State ('s2', 's0'), with labels {'green', 'h2'}, Pr = 0.42122366709344317
#   State ('s2', 's1'), with labels {'red', 'h2'}, Pr = 0.0
#   State ('s3', 's0'), with labels {'h3', 'green'}, Pr = 0.5528560630601442
#   State ('s3', 's1'), with labels {'h3', 'red'}, Pr = 0.0
